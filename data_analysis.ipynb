# %%
import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("库导入成功!")

# %% [markdown]
# ## 数据分析环境准备
#
# 这个 notebook 已经导入了必要的库：
# - **NumPy**: 用于数值计算和数组操作
# - **Pandas**: 用于数据处理和分析
#
# 您可以开始进行数据分析工作了！

# %%
# 示例：创建一些测试数据
data = {
    '日期': pd.date_range('2024-01-01', periods=10),
    '数值': np.random.randn(10),
    '分类': np.random.choice(['A', 'B', 'C'], 10)
}

df = pd.DataFrame(data)
print("示例数据框:")
print(df.head())

# %%
data
